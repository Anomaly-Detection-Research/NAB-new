# %%
import warnings
import itertools
import pandas
import math
import sys
import os
import numpy as np

# %%
def make_result_files(input_xlsx_file, input_csv_file, output_csv_file):
    input_xlsx_DataFrame = pandas.read_excel(input_xlsx_file)
    training_data_size = list(input_xlsx_DataFrame.columns.values)[-1]
    model_input = input_xlsx_DataFrame[training_data_size][3]
    
    training_data_size = int(training_data_size.split(': ')[1])
    model_input = model_input.split(': ')[1]
    model_input = int(model_input.split('x')[0])*int(model_input.split('x')[1])

    time_offset = training_data_size + model_input
    print("Time offset in " +input_xlsx_file + " : " + str(time_offset) )
    
    input_csv_DataFrame = pandas.read_csv(input_csv_file)
    
    xlsx_input_values = np.array(input_xlsx_DataFrame['Value'])
    xlsx_anomaly_detections = np.array(input_xlsx_DataFrame['DTW Detection'])
    xlsx_DTW_similarity = np.array(input_xlsx_DataFrame['DTW Similarity'])
    xlsx_label = np.array(input_xlsx_DataFrame['Anomaly'])
    csv_values = np.array(input_csv_DataFrame['value'])
    
    if csv_values[time_offset] != xlsx_input_values[0]:
        print(" ### ERROR ### : time offset mismatch in " + input_xlsx_file)
        print("offset cvs value : "+str(xlsx_input_values[0]))
        print("offset xlsx value : "+str(csv_values[time_offset]))
#         return 1
    else:
        print("time offset is correct in " + input_xlsx_file)
    
    anomaly_score = np.zeros(len(csv_values))
    label = np.zeros(len(csv_values))
    for i in range(0, len(csv_values)-1):
        tmp = xlsx_anomaly_detections[i]
        if not np.isnan(tmp):
            anomaly_score[i+time_offset] = 1
        if not np.isnan(xlsx_label[i]):
            label[i] = 1
    
    output_csv_DataFrame =  pandas.DataFrame(
                        dict(value=csv_values,
                            anomaly_score=anomaly_score,
                            DTW_similarity=xlsx_DTW_similarity,
                            label=label),
                            index=input_csv_DataFrame['timestamp'])
    output_csv_DataFrame.to_csv(output_csv_file)
    print("Done writing " + output_csv_file)
    return 0

def change_file_from_xlsx_to_csv(xlsx_file):
    xlsx_file = xlsx_file[:-4]
    return xlsx_file + 'csv'

def get_output_csv_file(input_csv,detector_name):
    input_csv = input_csv.split('/')
    input_csv = input_csv[0] +'/'+ input_csv[1] +'/'+ detector_name +'/'+ input_csv[3] +'/'+ detector_name +'_'+ input_csv[4]
    return input_csv

def get_summary_file(detector):
    detector_summary_file = "../results/numentaTM/numentaTM_standard_scores.csv"
    detector_summary_file = detector_summary_file.split('/')
    file_name = detector_summary_file[3].split('_')
    file_name = detector + '_' + file_name[1] + '_' + file_name[2]
    detector_summary_file = detector_summary_file[0] +'/'+ detector_summary_file[1] +'/'+ detector +'/'+ file_name
    return detector_summary_file

def generate_final_score_summary(detectors, outputfile):
         
    final_DataFrame = pandas.read_csv(get_summary_file(detectors[0]))
    Summary_colomns = {}
    for d in detectors:
        DataFrame = pandas.read_csv(get_summary_file(d), index_col='File')
        Summary_colomns[d] = DataFrame['Score']
    
    final_DataFrame =  pandas.DataFrame(Summary_colomns, index=final_DataFrame['File'])
    
    final_DataFrame.to_csv(outputfile)
    print("Done writing " + outputfile)

# %%
input_xlsx_files = [
    # 2 offset erros are due to rounding off
    "../results/LSTMCNnet original/artificialNoAnomaly/art_daily_no_noise.xlsx",
    "../results/LSTMCNnet original/artificialNoAnomaly/art_daily_perfect_square_wave.xlsx",
    "../results/LSTMCNnet original/artificialNoAnomaly/art_daily_small_noise.xlsx",  # offset error
    "../results/LSTMCNnet original/artificialNoAnomaly/art_flatline.xlsx",
    "../results/LSTMCNnet original/artificialNoAnomaly/art_noisy.xlsx",  # offset error
    
    # 2 offset erros are due to rounding off
    "../results/LSTMCNnet original/artificialWithAnomaly/art_daily_flatmiddle.xlsx",
    "../results/LSTMCNnet original/artificialWithAnomaly/art_daily_jumpsdown.xlsx",  # offset error
    "../results/LSTMCNnet original/artificialWithAnomaly/art_daily_jumpsup.xlsx",
    "../results/LSTMCNnet original/artificialWithAnomaly/art_daily_nojump.xlsx",  # offset error
    "../results/LSTMCNnet original/artificialWithAnomaly/art_increase_spike_density.xlsx",
    "../results/LSTMCNnet original/artificialWithAnomaly/art_load_balancer_spikes.xlsx",

    # 6 offset erros are due to rounding off
    "../results/LSTMCNnet original/realAdExchange/exchange-2_cpc_results.xlsx",  # offset error
    "../results/LSTMCNnet original/realAdExchange/exchange-2_cpm_results.xlsx",  # offset error
    "../results/LSTMCNnet original/realAdExchange/exchange-3_cpc_results.xlsx",  # offset error
    "../results/LSTMCNnet original/realAdExchange/exchange-3_cpm_results.xlsx",  # offset error
    "../results/LSTMCNnet original/realAdExchange/exchange-4_cpc_results.xlsx",  # offset error
    "../results/LSTMCNnet original/realAdExchange/exchange-4_cpm_results.xlsx",  # offset error
    
    # error 2 offset erros CRITICAL ERROR 
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_5f5533.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_24ae8d.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_53ea38.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_77c1ca.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_825cc2.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_ac20cd.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_c6585a.xlsx",  # offset error CRITICAL ERROR
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_fe7f93.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_disk_write_bytes_1ef3de.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_disk_write_bytes_c0d644.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_network_in_5abac7.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/ec2_network_in_257a54.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/elb_request_count_8c0756.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/grok_asg_anomaly.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/iio_us-east-1_i-a2eb1cd9_NetworkIn.xlsx",  # offset error
    "../results/LSTMCNnet original/realAWSCloudwatch/rds_cpu_utilization_cc0c53.xlsx",
    "../results/LSTMCNnet original/realAWSCloudwatch/rds_cpu_utilization_e47b3b.xlsx",
    
    # 2 offset erros are due to rounding off
    "../results/LSTMCNnet original/realKnownCause/ambient_temperature_system_failure.xlsx",  # offset error
    "../results/LSTMCNnet original/realKnownCause/cpu_utilization_asg_misconfiguration.xlsx",
    "../results/LSTMCNnet original/realKnownCause/ec2_request_latency_system_failure.xlsx",
    "../results/LSTMCNnet original/realKnownCause/machine_temperature_system_failure.xlsx", # offset error
    "../results/LSTMCNnet original/realKnownCause/nyc_taxi.xlsx",
    "../results/LSTMCNnet original/realKnownCause/rogue_agent_key_hold.xlsx",
    "../results/LSTMCNnet original/realKnownCause/rogue_agent_key_updown.xlsx",

    # no errors
    "../results/LSTMCNnet original/realTraffic/occupancy_6005.xlsx",
    "../results/LSTMCNnet original/realTraffic/occupancy_t4013.xlsx",
    "../results/LSTMCNnet original/realTraffic/speed_6005.xlsx",
    "../results/LSTMCNnet original/realTraffic/speed_7578.xlsx",
    "../results/LSTMCNnet original/realTraffic/speed_t4013.xlsx",
    "../results/LSTMCNnet original/realTraffic/TravelTime_387.xlsx",
    "../results/LSTMCNnet original/realTraffic/TravelTime_451.xlsx",
    
#     # no errors
    "../results/LSTMCNnet original/realTweets/Twitter_volume_AAPL.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_AMZN.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_CRM.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_CVS.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_FB.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_GOOG.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_IBM.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_KO.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_PFE.xlsx",
    "../results/LSTMCNnet original/realTweets/Twitter_volume_UPS.xlsx"
]

for f in input_xlsx_files:
    input_csv = change_file_from_xlsx_to_csv(f)
    output_csv = get_output_csv_file(input_csv,'LSTMCNnet')
    make_result_files(f,input_csv,output_csv)
# Out:
# Time offset in ../results/LSTMCNnet original/artificialNoAnomaly/art_daily_no_noise.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialNoAnomaly/art_daily_no_noise.xlsx
# Done writing ../results/LSTMCNnet/artificialNoAnomaly/LSTMCNnet_art_daily_no_noise.csv
# Time offset in ../results/LSTMCNnet original/artificialNoAnomaly/art_daily_perfect_square_wave.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialNoAnomaly/art_daily_perfect_square_wave.xlsx
# Done writing ../results/LSTMCNnet/artificialNoAnomaly/LSTMCNnet_art_daily_perfect_square_wave.csv
# Time offset in ../results/LSTMCNnet original/artificialNoAnomaly/art_daily_small_noise.xlsx : 620
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/artificialNoAnomaly/art_daily_small_noise.xlsx
# offset cvs value : 19.9019
# offset xlsx value : 19.901902860899998
# Done writing ../results/LSTMCNnet/artificialNoAnomaly/LSTMCNnet_art_daily_small_noise.csv
# Time offset in ../results/LSTMCNnet original/artificialNoAnomaly/art_flatline.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialNoAnomaly/art_flatline.xlsx
# Done writing ../results/LSTMCNnet/artificialNoAnomaly/LSTMCNnet_art_flatline.csv
# Time offset in ../results/LSTMCNnet original/artificialNoAnomaly/art_noisy.xlsx : 620
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/artificialNoAnomaly/art_noisy.xlsx
# offset cvs value : 11.7061
# offset xlsx value : 11.7061410438
# Done writing ../results/LSTMCNnet/artificialNoAnomaly/LSTMCNnet_art_noisy.csv
# Time offset in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_flatmiddle.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_flatmiddle.xlsx
# Done writing ../results/LSTMCNnet/artificialWithAnomaly/LSTMCNnet_art_daily_flatmiddle.csv
# Time offset in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_jumpsdown.xlsx : 630
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_jumpsdown.xlsx
# offset cvs value : 18.6835
# offset xlsx value : 18.6834817354
# Done writing ../results/LSTMCNnet/artificialWithAnomaly/LSTMCNnet_art_daily_jumpsdown.csv
# Time offset in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_jumpsup.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_jumpsup.xlsx
# Done writing ../results/LSTMCNnet/artificialWithAnomaly/LSTMCNnet_art_daily_jumpsup.csv
# Time offset in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_nojump.xlsx : 620
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/artificialWithAnomaly/art_daily_nojump.xlsx
# offset cvs value : 19.6587
# offset xlsx value : 19.6587355433
# Done writing ../results/LSTMCNnet/artificialWithAnomaly/LSTMCNnet_art_daily_nojump.csv
# Time offset in ../results/LSTMCNnet original/artificialWithAnomaly/art_increase_spike_density.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialWithAnomaly/art_increase_spike_density.xlsx
# Done writing ../results/LSTMCNnet/artificialWithAnomaly/LSTMCNnet_art_increase_spike_density.csv
# Time offset in ../results/LSTMCNnet original/artificialWithAnomaly/art_load_balancer_spikes.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/artificialWithAnomaly/art_load_balancer_spikes.xlsx
# Done writing ../results/LSTMCNnet/artificialWithAnomaly/LSTMCNnet_art_load_balancer_spikes.csv
# Time offset in ../results/LSTMCNnet original/realAdExchange/exchange-2_cpc_results.xlsx : 260
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAdExchange/exchange-2_cpc_results.xlsx
# offset cvs value : 0.0657076
# offset xlsx value : 0.0657076101469
# Done writing ../results/LSTMCNnet/realAdExchange/LSTMCNnet_exchange-2_cpc_results.csv
# Time offset in ../results/LSTMCNnet original/realAdExchange/exchange-2_cpm_results.xlsx : 220
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAdExchange/exchange-2_cpm_results.xlsx
# offset cvs value : 0.132642
# offset xlsx value : 0.132642082613
# Done writing ../results/LSTMCNnet/realAdExchange/LSTMCNnet_exchange-2_cpm_results.csv
# Time offset in ../results/LSTMCNnet original/realAdExchange/exchange-3_cpc_results.xlsx : 220
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAdExchange/exchange-3_cpc_results.xlsx
# offset cvs value : 0.142296
# offset xlsx value : 0.142295918367
# Done writing ../results/LSTMCNnet/realAdExchange/LSTMCNnet_exchange-3_cpc_results.csv
# Time offset in ../results/LSTMCNnet original/realAdExchange/exchange-3_cpm_results.xlsx : 220
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAdExchange/exchange-3_cpm_results.xlsx
# offset cvs value : 0.638281
# offset xlsx value : 0.638280829834
# Done writing ../results/LSTMCNnet/realAdExchange/LSTMCNnet_exchange-3_cpm_results.csv
# Time offset in ../results/LSTMCNnet original/realAdExchange/exchange-4_cpc_results.xlsx : 220
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAdExchange/exchange-4_cpc_results.xlsx
# offset cvs value : 0.0652293
# offset xlsx value : 0.0652292595897
# Done writing ../results/LSTMCNnet/realAdExchange/LSTMCNnet_exchange-4_cpc_results.csv
# Time offset in ../results/LSTMCNnet original/realAdExchange/exchange-4_cpm_results.xlsx : 220
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAdExchange/exchange-4_cpm_results.xlsx
# offset cvs value : 0.532838
# offset xlsx value : 0.532838013513
# Done writing ../results/LSTMCNnet/realAdExchange/LSTMCNnet_exchange-4_cpm_results.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_5f5533.xlsx : 340
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_5f5533.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_5f5533.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_24ae8d.xlsx : 640
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_24ae8d.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_24ae8d.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_53ea38.xlsx : 340
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_53ea38.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_53ea38.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_77c1ca.xlsx : 340
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_77c1ca.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_77c1ca.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_825cc2.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_825cc2.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_825cc2.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_ac20cd.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_ac20cd.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_ac20cd.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_c6585a.xlsx : 360
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_c6585a.xlsx
# offset cvs value : 0.068
# offset xlsx value : 0.066
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_c6585a.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_fe7f93.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_cpu_utilization_fe7f93.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_cpu_utilization_fe7f93.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_disk_write_bytes_1ef3de.xlsx : 640
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_disk_write_bytes_1ef3de.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_disk_write_bytes_1ef3de.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_disk_write_bytes_c0d644.xlsx : 630
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_disk_write_bytes_c0d644.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_disk_write_bytes_c0d644.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_network_in_5abac7.xlsx : 640
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_network_in_5abac7.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_network_in_5abac7.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_network_in_257a54.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/ec2_network_in_257a54.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_ec2_network_in_257a54.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/elb_request_count_8c0756.xlsx : 460
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/elb_request_count_8c0756.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_elb_request_count_8c0756.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/grok_asg_anomaly.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/grok_asg_anomaly.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_grok_asg_anomaly.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/iio_us-east-1_i-a2eb1cd9_NetworkIn.xlsx : 160
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realAWSCloudwatch/iio_us-east-1_i-a2eb1cd9_NetworkIn.xlsx
# offset cvs value : 865115.0
# offset xlsx value : 865114.8
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_iio_us-east-1_i-a2eb1cd9_NetworkIn.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/rds_cpu_utilization_cc0c53.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/rds_cpu_utilization_cc0c53.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_rds_cpu_utilization_cc0c53.csv
# Time offset in ../results/LSTMCNnet original/realAWSCloudwatch/rds_cpu_utilization_e47b3b.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realAWSCloudwatch/rds_cpu_utilization_e47b3b.xlsx
# Done writing ../results/LSTMCNnet/realAWSCloudwatch/LSTMCNnet_rds_cpu_utilization_e47b3b.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/ambient_temperature_system_failure.xlsx : 670
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realKnownCause/ambient_temperature_system_failure.xlsx
# offset cvs value : 73.9995
# offset xlsx value : 73.99954302
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_ambient_temperature_system_failure.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/cpu_utilization_asg_misconfiguration.xlsx : 1060
# time offset is correct in ../results/LSTMCNnet original/realKnownCause/cpu_utilization_asg_misconfiguration.xlsx
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_cpu_utilization_asg_misconfiguration.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/ec2_request_latency_system_failure.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realKnownCause/ec2_request_latency_system_failure.xlsx
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_ec2_request_latency_system_failure.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/machine_temperature_system_failure.xlsx : 1260
#  ### ERROR ### : time offset mismatch in ../results/LSTMCNnet original/realKnownCause/machine_temperature_system_failure.xlsx
# offset cvs value : 86.2719
# offset xlsx value : 86.27192087
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_machine_temperature_system_failure.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/nyc_taxi.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realKnownCause/nyc_taxi.xlsx
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_nyc_taxi.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/rogue_agent_key_hold.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realKnownCause/rogue_agent_key_hold.xlsx
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_rogue_agent_key_hold.csv
# Time offset in ../results/LSTMCNnet original/realKnownCause/rogue_agent_key_updown.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realKnownCause/rogue_agent_key_updown.xlsx
# Done writing ../results/LSTMCNnet/realKnownCause/LSTMCNnet_rogue_agent_key_updown.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/occupancy_6005.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realTraffic/occupancy_6005.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_occupancy_6005.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/occupancy_t4013.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realTraffic/occupancy_t4013.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_occupancy_t4013.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/speed_6005.xlsx : 360
# time offset is correct in ../results/LSTMCNnet original/realTraffic/speed_6005.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_speed_6005.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/speed_7578.xlsx : 260
# time offset is correct in ../results/LSTMCNnet original/realTraffic/speed_7578.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_speed_7578.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/speed_t4013.xlsx : 260
# time offset is correct in ../results/LSTMCNnet original/realTraffic/speed_t4013.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_speed_t4013.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/TravelTime_387.xlsx : 260
# time offset is correct in ../results/LSTMCNnet original/realTraffic/TravelTime_387.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_TravelTime_387.csv
# Time offset in ../results/LSTMCNnet original/realTraffic/TravelTime_451.xlsx : 260
# time offset is correct in ../results/LSTMCNnet original/realTraffic/TravelTime_451.xlsx
# Done writing ../results/LSTMCNnet/realTraffic/LSTMCNnet_TravelTime_451.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_AAPL.xlsx : 260
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_AAPL.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_AAPL.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_AMZN.xlsx : 1060
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_AMZN.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_AMZN.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_CRM.xlsx : 1060
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_CRM.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_CRM.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_CVS.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_CVS.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_CVS.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_FB.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_FB.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_FB.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_GOOG.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_GOOG.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_GOOG.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_IBM.xlsx : 660
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_IBM.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_IBM.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_KO.xlsx : 620
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_KO.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_KO.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_PFE.xlsx : 1200
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_PFE.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_PFE.csv
# Time offset in ../results/LSTMCNnet original/realTweets/Twitter_volume_UPS.xlsx : 800
# time offset is correct in ../results/LSTMCNnet original/realTweets/Twitter_volume_UPS.xlsx
# Done writing ../results/LSTMCNnet/realTweets/LSTMCNnet_Twitter_volume_UPS.csv

# %%
# Have to add label or run python run.py --optimize -d LSTMCNnet
# generate score by python run.py --score -d LSTMCNnet
generate_final_score_summary(['numenta','LSTMCNnet','TSA_ARMA'],'../results/score_summary.csv')
# Out:
# Done writing ../results/score_summary.csv
